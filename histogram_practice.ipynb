# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
# 1. histogram using opencv  
###############################################
im_path = 'sky_castle.jpg'

# %%
im_gray = cv2.imread(im_path, cv2.IMREAD_GRAYSCALE)

# %%
print(im_gray)
# Out:
# [[ 88  87  85 ...  86  86  86]
#  [ 88  87  85 ...  83  84  84]
#  [ 87  86  85 ...  80  82  83]
#  ...
#  [109 109 109 ... 176 176 176]
#  [109 109 109 ... 175 175 175]
#  [109 109 109 ... 174 174 174]]

# %%
hist = cv2.calcHist([im_gray], channels =[0], mask = None, histSize=[256],ranges=[0.0,256.0]) 
# (이미지, 그레이 = 0, mask:일부만 계산 , 히스토그램 사이즈, 265개로 나눠서)

# %%
#이미지 사이즈 = np.sum(hist)
print("sum:", np.sum(hist), " = res:", im_gray.shape[0]*im_gray.shape[1])
print(type(hist), hist.shape)
plt.subplot(1,2,1)
plt.imshow(im_gray, cmap='gray')
plt.subplot(1,2,2)
plt.plot(hist)
plt.grid()
plt.show()
# Out:
# sum: 196608.0  = res: 196608
# <class 'numpy.ndarray'> (256, 1)

# %%
# 2. 2D histogram using opencv  
#    (H => 1st index => y in image ,S => 2nd index in x in image)   
###############################################
im_bgr  = cv2.imread(im_path)
im_hsv = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2HSV)

# %%
plt.subplot(1,2,1)
plt.imshow(im_bgr[:,:,::-1])
plt.subplot(1,2,2)
plt.imshow(im_hsv)
plt.show()

# %%
# hist = cv2.calcHist([im_hsv], channels =[0,1], mask = None, histSize=[18, 25],ranges=[0.,181., 0., 256.]) 
# h=18, s = 25개

# %%
im_bgr  = cv2.imread(im_path)
im_hsv = cv2.cvtColor(im_bgr, cv2.COLOR_BGR2HSV)
hist = cv2.calcHist([im_hsv], channels =[0,1], mask = None, histSize=[18, 25],ranges=[0.,181., 0., 256.]) 
print("sum:", np.sum(hist), " = res:", im_hsv.shape[0]*im_hsv.shape[1])

#plt.subplot(1,2,1)
plt.imshow(hist, cmap='gray')
plt.xlabel('Saturation')
plt.ylabel('Hue')
#plt.grid()
plt.show()    
    
    
#파란색 ~ Hue  10 에 위치 
#
# Out:
# sum: 196608.0  = res: 196608

# %%
#equalization
im_gray = cv2.imread(im_path, cv2.IMREAD_GRAYSCALE)
im_eq = cv2.equalizeHist(im_gray)

# %%
plt.subplot(1,2,1)
plt.imshow(im_gray, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(im_eq, cmap='gray')
plt.show()

# %%
img_path = 'forest.jpg'
img_gray = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
img_eq = cv2.equalizeHist(img_gray)

# %%
plt.subplot(1,2,1)
plt.imshow(img_gray, cmap='gray')
plt.subplot(1,2,2)
plt.imshow(img_eq, cmap='gray')
plt.show()

# %%
#creatCLAHE ~~ 다시 보기 
clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize(8,8))
im_eq2 = clahe.apply(img_gray)
# Out:
#   File "C:\Users\user\AppData\Local\Temp/ipykernel_16444/905430809.py", line 2
#     clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize(8,8))
#                                           ^
# SyntaxError: positional argument follows keyword argument
